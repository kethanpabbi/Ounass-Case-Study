# %%
# %pip install pandas pyarrow scikit-learn
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: pyarrow in /opt/homebrew/lib/python3.11/site-packages (23.0.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_parquet("reco_model_data.parquet")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nFirst 3 rows:")
df.head(3)
# Out:
# Shape: (6477142, 11)
#
# Columns: ['dt', 'session_id', 'event_name', 'product_id', 'image_url', 'productclass', 'class', 'subclass', 'designer', 'name', 'gender']
#
# Dtypes:
#  dt              object
# session_id       int64
# event_name      object
# product_id       int64
# image_url       object
# productclass    object
# class           object
# subclass        object
# designer        object
# name            object
# gender          object
# dtype: object
#
# First 3 rows:
#            dt  session_id event_name  product_id  \
# 0  2025-01-23      534295      click        2368
# 1  2025-01-09      684505      click        2368
# 2  2025-01-20      314905      click        2369
#
#                                            image_url productclass  \
# 0  https://ounass.com//2/1/212588355_nocolor_in.j...       Beauty
# 1  https://ounass.com//2/1/212588355_nocolor_in.j...       Beauty
# 2  https://ounass.com//2/1/212588361_nocolor_in.j...       Beauty
#
#                              class        subclass designer  \
# 0  Creams, Moisturisers And Serums  Eye Treatments   Sensai
# 1  Creams, Moisturisers And Serums  Eye Treatments   Sensai
# 2            Accessories And Tools    Face Brushes   Sensai
#
#                                                 name  gender
# 0  Cellular Performance Extra Intensive 10 Minute...  Unisex
# 1  Cellular Performance Extra Intensive 10 Minute...  Unisex
# 2                                       Cheek Brush   Womens

# %%
print("Nulls:\n", df.isnull().sum())
print("\nUnique values per column:")
for col in df.columns:
    print(f"  {col}: {df[col].nunique()} unique — sample:", df[col].dropna().unique()[:5])
# Out:
# Nulls:
#  dt                 0
# session_id         0
# event_name         0
# product_id         0
# image_url       3434
# productclass     297
# class              0
# subclass           0
# designer         800
# name               0
# gender          9781
# dtype: int64
#
# Unique values per column:
#   dt: 31 unique — sample: ['2025-01-23' '2025-01-09' '2025-01-20' '2025-01-26' '2025-01-30']
#   session_id: 169800 unique — sample: [534295 684505 314905 141190 459680]
#   event_name: 1 unique — sample: ['click']
#   product_id: 112145 unique — sample: [2368 2369 2370 2371 2372]
#   image_url: 125406 unique — sample: ['https://ounass.com//2/1/212588355_nocolor_in.jpg?ts=1640726240.7545'
#  'https://ounass.com//2/1/212588361_nocolor_in.jpg?ts=1640728805.1762'
#  'https://ounass.com//2/1/212588549_nocolor_in.jpg?ts=1587289670.1673'
#  'https://ounass.com//2/1/212588550_nocolor_in.jpg?ts=1587289672.6886'
#  'https://ounass.com//2/1/212589468_navy_in.jpg?ts=1547034411.815']
#   productclass: 7 unique — sample: ['Beauty' 'Clothing' 'Shoes' 'Accessories' 'Bags']
#   class: 137 unique — sample: ['Creams, Moisturisers And Serums' 'Accessories And Tools' 'Face'
#  'Trousers' 'Sweatshirts']
#   subclass: 595 unique — sample: ['Eye Treatments' 'Face Brushes' 'Foundation' 'Casual' 'Crew Neck']
#   designer: 1313 unique — sample: ['Sensai' 'CLINIQUE' 'Bottega Veneta' 'Gucci' 'Miansai']
#   name: 82638 unique — sample: ['Cellular Performance Extra Intensive 10 Minute Revitalising Pads, 6ml x 10 sachets '
#  'Cheek Brush ' 'WN 38 Stone Even Better™ Makeup SPF15, 30ml '
#  'WN 69 Cardamom Even Better™ Makeup SPF15, 30ml '
#  'Dark-Navy Cotton Chinos ']
#   gender: 8 unique — sample: ['Unisex' 'Womens' 'Mens' 'Boy' 'Home']

# %%
df.sample(5)
# Out:
#                  dt  session_id event_name  product_id  \
# 1081845  2025-01-11      589890      click       28640
# 318666   2025-01-29      757855      click        8836
# 6461658  2025-01-25      797395      click      119920
# 2752356  2025-01-31      798655      click       71321
# 1701174  2025-01-20      819815      click       40421
#
#                                                  image_url productclass  \
# 1081845  https://ounass.com//2/1/216429118_black_in.jpg...     Clothing
# 318666   https://ounass.com//2/1/214586911_black_in.jpg...  Accessories
# 6461658  https://ounass.com//2/1/218092164_red_in.jpg?t...     Clothing
# 2752356  https://ounass.com//2/1/217429587_blk_in.jpg?t...     Clothing
# 1701174  https://ounass.com//2/1/216865119_red_in.jpg?t...     Clothing
#
#                        class      subclass            designer  \
# 1081845             Knitwear       Dresses  Elisabetta Franchi
# 318666   Small Leather Goods       Pouches       SAINT LAURENT
# 6461658              Dresses   Long Sleeve          Meem Label
# 2752356              Dresses  One Shoulder                Amri
# 1701174              Dresses    Sleeveless     Dolce & Gabbana
#
#                                                       name  gender
# 1081845                          Midi Dress in Ribbed-knit  Womens
# 318666   Uptown Pouch in Grain de Poudre Embossed Leath...  Womens
# 6461658                                   Rayna Midi Dress  Womens
# 2752356  Embellished Off-shoulder Maxi Dress in Stretch...  Womens
# 1701174                        Sequinned Draped Maxi Dress  Womens
